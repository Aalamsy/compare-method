# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

# Parameter distribusi
mean = 5.85
std_dev = 1.31

# Rentang nilai x
x = np.linspace(mean - 3*std_dev, mean + 3*std_dev, 100)

# Hitung nilai fungsi densitas
y = norm.pdf(x, mean, std_dev)

# Buat plot
plt.figure(figsize=(8, 6))
plt.plot(x, y, label=f'Normal Distribution\nMean = {mean}, Std Dev = {std_dev}')
plt.fill_between(x, y, alpha=0.2)
plt.title('Kurva Distribusi Normal')
plt.xlabel('Nilai x')
plt.ylabel('Kepadatan Probabilitas')
plt.legend()
plt.grid(True)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

# Parameter distribusi
mean = 5.85
std_dev = 1.31

# Rentang nilai x dari 1 hingga 7
x = np.linspace(1, 7, 100)

# Hitung nilai fungsi densitas
y = norm.pdf(x, mean, std_dev)

# Buat plot
plt.figure(figsize=(8, 6))
plt.plot(x, y, label=f'Normal Distribution\nMean = {mean}, Std Dev = {std_dev}')
plt.fill_between(x, y, alpha=0.2)
plt.title('Kurva Distribusi Normal')
plt.xlabel('Nilai x')
plt.ylabel('Kepadatan Probabilitas')
plt.legend()
plt.grid(True)
plt.show()
